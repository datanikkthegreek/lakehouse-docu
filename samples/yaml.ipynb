# %%
import requests
import os
import sys
import platform
from lakehouse import bronze, silver
from pyspark.sql import DataFrame, SparkSession
from delta import DeltaTable, configure_spark_with_delta_pip
from delta.tables import DeltaMergeBuilder
from pyspark.sql import functions as F
from pyspark.sql import DataFrame
import json

# %%
if platform.system() == "Windows":
    os.environ["PYSPARK_PYTHON"] = sys.executable
    os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable
    print("Adding Python ENV variables on Windows")
# Out:
# Adding Python ENV variables on Windows

# %%
builder = (
    SparkSession.builder.appName("Data with Nikk the Greek Spark Session")
    .master("local[4]")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config(
        "spark.sql.catalog.spark_catalog",
        "org.apache.spark.sql.delta.catalog.DeltaCatalog",
    )
)
spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
CATALOG = spark.catalog.currentCatalog()

# %% [markdown]
# # 1. Set Up and Bronze Data

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.bronze")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.silver")
# Out:
# DataFrame[]

# %%
options = {"catalog": CATALOG, "target_schema": "bronze"}

# %%
@F.udf(returnType="STRING")
def get_properties(url):
    json_request = requests.get(url).json()
    return json.dumps(json_request["result"]["properties"])

# %%
class StarWarsBronze(bronze.Bronze):
    def custom_load(self, table):
        results = []
        query = f"https://swapi.tech/api/{table}"
        json_request = requests.get(query).json()
        results.extend(json_request["results"])

        while json_request["next"]:
            json_request = requests.get(json_request["next"]).json()
            results.extend(json_request["results"])
        return spark.createDataFrame(results)

    def custom_transform(self, sdf: DataFrame, table: str) -> DataFrame:
        return sdf.withColumn("properties", get_properties(F.col("url")))


bronze_instance = StarWarsBronze(spark, **options)

# %%
bronze_instance.load().transform().write(mode="overwrite").execute("people", "planets")

# %%
sdf = spark.sql(f"SELECT * FROM {CATALOG}.bronze.people")
print(f"No. Rows: {sdf.count()}")
sdf.show()
# Out:
# No. Rows: 82
# +--------------------+-------------------+---+--------------------+--------------------+
# |         LH_BronzeTS|               name|uid|                 url|          properties|
# +--------------------+-------------------+---+--------------------+--------------------+
# |2025-02-18 21:11:...|        Cliegg Lars| 62|https://www.swapi...|{"height": "183",...|
# |2025-02-18 21:11:...|  Poggle the Lesser| 63|https://www.swapi...|{"height": "183",...|
# |2025-02-18 21:11:...|    Luminara Unduli| 64|https://www.swapi...|{"height": "170",...|
# |2025-02-18 21:11:...|      Barriss Offee| 65|https://www.swapi...|{"height": "166",...|
# |2025-02-18 21:11:...|              Dormé| 66|https://www.swapi...|{"height": "165",...|
# |2025-02-18 21:11:...|              Dooku| 67|https://www.swapi...|{"height": "193",...|
# |2025-02-18 21:11:...|Bail Prestor Organa| 68|https://www.swapi...|{"height": "191",...|
# |2025-02-18 21:11:...|         Jango Fett| 69|https://www.swapi...|{"height": "183",...|
# |2025-02-18 21:11:...|         Zam Wesell| 70|https://www.swapi...|{"height": "168",...|
# |2025-02-18 21:11:...|    Dexter Jettster| 71|https://www.swapi...|{"height": "198",...|
# |2025-02-18 21:11:...|            Lama Su| 72|https://www.swapi...|{"height": "229",...|
# |2025-02-18 21:11:...|            Taun We| 73|https://www.swapi...|{"height": "213",...|
# |2025-02-18 21:11:...|         Jocasta Nu| 74|https://www.swapi...|{"height": "167",...|
# |2025-02-18 21:11:...|             R4-P17| 75|https://www.swapi...|{"height": "96", ...|
# |2025-02-18 21:11:...|         Wat Tambor| 76|https://www.swapi...|{"height": "193",...|
# |2025-02-18 21:11:...|           San Hill| 77|https://www.swapi...|{"height": "191",...|
# |2025-02-18 21:11:...|           Shaak Ti| 78|https://www.swapi...|{"height": "178",...|
# |2025-02-18 21:11:...|           Grievous| 79|https://www.swapi...|{"height": "216",...|
# |2025-02-18 21:11:...|            Tarfful| 80|https://www.swapi...|{"height": "234",...|
# |2025-02-18 21:11:...|    Raymus Antilles| 81|https://www.swapi...|{"height": "188",...|
# +--------------------+-------------------+---+--------------------+--------------------+
# only showing top 20 rows

# %%
sdf = spark.sql(f"SELECT * FROM {CATALOG}.bronze.planets")
print(f"No. Rows: {sdf.count()}")
sdf.show(truncate=False)
# Out:
# No. Rows: 60
# +-------------------------+--------------+---+-------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |LH_BronzeTS              |name          |uid|url                                  |properties                                                                                                                                                                                                                                                                                                                                                                                    |
# +-------------------------+--------------+---+-------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2025-02-18 21:12:02.21629|Mon Cala      |31 |https://www.swapi.tech/api/planets/31|{"diameter": "11030", "rotation_period": "21", "orbital_period": "398", "gravity": "1", "population": "27000000000", "climate": "temperate", "terrain": "oceans, reefs, islands", "surface_water": "100", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Mon Cala", "url": "https://www.swapi.tech/api/planets/31"}                                    |
# |2025-02-18 21:12:02.21629|Chandrila     |32 |https://www.swapi.tech/api/planets/32|{"diameter": "13500", "rotation_period": "20", "orbital_period": "368", "gravity": "1", "population": "1200000000", "climate": "temperate", "terrain": "plains, forests", "surface_water": "40", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Chandrila", "url": "https://www.swapi.tech/api/planets/32"}                                            |
# |2025-02-18 21:12:02.21629|Sullust       |33 |https://www.swapi.tech/api/planets/33|{"diameter": "12780", "rotation_period": "20", "orbital_period": "263", "gravity": "1", "population": "18500000000", "climate": "superheated", "terrain": "mountains, volcanoes, rocky deserts", "surface_water": "5", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Sullust", "url": "https://www.swapi.tech/api/planets/33"}                        |
# |2025-02-18 21:12:02.21629|Toydaria      |34 |https://www.swapi.tech/api/planets/34|{"diameter": "7900", "rotation_period": "21", "orbital_period": "184", "gravity": "1", "population": "11000000", "climate": "temperate", "terrain": "swamps, lakes", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Toydaria", "url": "https://www.swapi.tech/api/planets/34"}                                             |
# |2025-02-18 21:12:02.21629|Malastare     |35 |https://www.swapi.tech/api/planets/35|{"diameter": "18880", "rotation_period": "26", "orbital_period": "201", "gravity": "1.56", "population": "2000000000", "climate": "arid, temperate, tropical", "terrain": "swamps, deserts, jungles, mountains", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Malastare", "url": "https://www.swapi.tech/api/planets/35"}|
# |2025-02-18 21:12:02.21629|Dathomir      |36 |https://www.swapi.tech/api/planets/36|{"diameter": "10480", "rotation_period": "24", "orbital_period": "491", "gravity": "0.9", "population": "5200", "climate": "temperate", "terrain": "forests, deserts, savannas", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Dathomir", "url": "https://www.swapi.tech/api/planets/36"}                                 |
# |2025-02-18 21:12:02.21629|Ryloth        |37 |https://www.swapi.tech/api/planets/37|{"diameter": "10600", "rotation_period": "30", "orbital_period": "305", "gravity": "1", "population": "1500000000", "climate": "temperate, arid, subartic", "terrain": "mountains, valleys, deserts, tundra", "surface_water": "5", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Ryloth", "url": "https://www.swapi.tech/api/planets/37"}            |
# |2025-02-18 21:12:02.21629|Aleen Minor   |38 |https://www.swapi.tech/api/planets/38|{"diameter": "unknown", "rotation_period": "unknown", "orbital_period": "unknown", "gravity": "unknown", "population": "unknown", "climate": "unknown", "terrain": "unknown", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Aleen Minor", "url": "https://www.swapi.tech/api/planets/38"}                                 |
# |2025-02-18 21:12:02.21629|Vulpter       |39 |https://www.swapi.tech/api/planets/39|{"diameter": "14900", "rotation_period": "22", "orbital_period": "391", "gravity": "1", "population": "421000000", "climate": "temperate, artic", "terrain": "urban, barren", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Vulpter", "url": "https://www.swapi.tech/api/planets/39"}                                     |
# |2025-02-18 21:12:02.21629|Troiken       |40 |https://www.swapi.tech/api/planets/40|{"diameter": "unknown", "rotation_period": "unknown", "orbital_period": "unknown", "gravity": "unknown", "population": "unknown", "climate": "unknown", "terrain": "desert, tundra, rainforests, mountains", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Troiken", "url": "https://www.swapi.tech/api/planets/40"}      |
# |2025-02-18 21:12:02.21629|Tund          |41 |https://www.swapi.tech/api/planets/41|{"diameter": "12190", "rotation_period": "48", "orbital_period": "1770", "gravity": "unknown", "population": "0", "climate": "unknown", "terrain": "barren, ash", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Tund", "url": "https://www.swapi.tech/api/planets/41"}                                                    |
# |2025-02-18 21:12:02.21629|Haruun Kal    |42 |https://www.swapi.tech/api/planets/42|{"diameter": "10120", "rotation_period": "25", "orbital_period": "383", "gravity": "0.98", "population": "705300", "climate": "temperate", "terrain": "toxic cloudsea, plateaus, volcanoes", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Haruun Kal", "url": "https://www.swapi.tech/api/planets/42"}                   |
# |2025-02-18 21:12:02.21629|Cerea         |43 |https://www.swapi.tech/api/planets/43|{"diameter": "unknown", "rotation_period": "27", "orbital_period": "386", "gravity": "1", "population": "450000000", "climate": "temperate", "terrain": "verdant", "surface_water": "20", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Cerea", "url": "https://www.swapi.tech/api/planets/43"}                                                       |
# |2025-02-18 21:12:02.21629|Glee Anselm   |44 |https://www.swapi.tech/api/planets/44|{"diameter": "15600", "rotation_period": "33", "orbital_period": "206", "gravity": "1", "population": "500000000", "climate": "tropical, temperate", "terrain": "lakes, islands, swamps, seas", "surface_water": "80", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Glee Anselm", "url": "https://www.swapi.tech/api/planets/44"}                    |
# |2025-02-18 21:12:02.21629|Iridonia      |45 |https://www.swapi.tech/api/planets/45|{"diameter": "unknown", "rotation_period": "29", "orbital_period": "413", "gravity": "unknown", "population": "unknown", "climate": "unknown", "terrain": "rocky canyons, acid pools", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Iridonia", "url": "https://www.swapi.tech/api/planets/45"}                           |
# |2025-02-18 21:12:02.21629|Mygeeto       |16 |https://www.swapi.tech/api/planets/16|{"diameter": "10088", "rotation_period": "12", "orbital_period": "167", "gravity": "1 standard", "population": "19000000", "climate": "frigid", "terrain": "glaciers, mountains, ice canyons", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Mygeeto", "url": "https://www.swapi.tech/api/planets/16"}                    |
# |2025-02-18 21:12:02.21629|Felucia       |17 |https://www.swapi.tech/api/planets/17|{"diameter": "9100", "rotation_period": "34", "orbital_period": "231", "gravity": "0.75 standard", "population": "8500000", "climate": "hot, humid", "terrain": "fungus forests", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Felucia", "url": "https://www.swapi.tech/api/planets/17"}                                 |
# |2025-02-18 21:12:02.21629|Cato Neimoidia|18 |https://www.swapi.tech/api/planets/18|{"diameter": "0", "rotation_period": "25", "orbital_period": "278", "gravity": "1 standard", "population": "10000000", "climate": "temperate, moist", "terrain": "mountains, fields, forests, rock arches", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Cato Neimoidia", "url": "https://www.swapi.tech/api/planets/18"}|
# |2025-02-18 21:12:02.21629|Saleucami     |19 |https://www.swapi.tech/api/planets/19|{"diameter": "14920", "rotation_period": "26", "orbital_period": "392", "gravity": "unknown", "population": "1400000000", "climate": "hot", "terrain": "caves, desert, mountains, volcanoes", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Saleucami", "url": "https://www.swapi.tech/api/planets/19"}                   |
# |2025-02-18 21:12:02.21629|Stewjon       |20 |https://www.swapi.tech/api/planets/20|{"diameter": "0", "rotation_period": "unknown", "orbital_period": "unknown", "gravity": "1 standard", "population": "unknown", "climate": "temperate", "terrain": "grass", "surface_water": "unknown", "created": "2025-02-17T21:21:51.718Z", "edited": "2025-02-17T21:21:51.718Z", "name": "Stewjon", "url": "https://www.swapi.tech/api/planets/20"}                                        |
# +-------------------------+--------------+---+-------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
ddl_schema_planets = "diameter STRING, rotation_period STRING, orbital_period STRING, gravity STRING, population STRING, climate STRING, terrain STRING, surface_water STRING, created STRING, edited STRING, name STRING, url STRING"
ddl_schema_people = "height STRING, mass STRING, hair_color STRING, skin_color STRING, eye_color STRING, birth_year STRING, gender STRING, created STRING, edited STRING, name STRING, homeworld STRING, url STRING"
DDL_SCHEMAS = {"planets": ddl_schema_planets, "people": ddl_schema_people}

# %%
options = {
    "catalog": CATALOG,
    "source_schema": "bronze",
    "target_schema": "silver",
}

# %% [markdown]
# # 2 Overwrite

# %%
config = {
            "load": {
                "mode": "default",
                "filter": "all",
                "date_col": "LH_BronzeTS",
            },
            "transform": {
                "ignore_defaults": False,
                "transformation_order": ["add_dummy_col", "rename_columns", "tbl_transformations", "select_columns", "cast_column_types"],
                #"tbl_transformations": {"tbl": "custom_transform1"},
                "rename_columns":{"planets": {"dummy_col": "dummy"}, "people": {"dummy_col": "dummy"}},
                "select_columns": {"planets": ["LH_BronzeTS", "name", "uid", "url", "dummy"], "people": ["LH_BronzeTS", "name", "uid", "url", "dummy"]},
                "cast_column_types": {"planets": {"dummy": "string", "id": "int"}, "people": {"dummy": "string", "id": "int"}},
            },
            "write": {
                "mode": "overwrite",
                "merge_schema": True,
                "external": False,
            },
            "optimize": {
                "optimize": True,
                "optimize_full": False,
                "vacuum": True,
                "vacuum_lite": True,
                "analyze": False,
                "retention": 168,
                #"excl_cols": ["a", "b"],
            },
            "tblproperties": {
                #"clusterby": ["a", "b"],
                "deletion_vectors": True,
                "auto_compact": True,
                "optimize_write": True,
                "change_data_feed": True,
                "row_tracking": True,
                "type_widening": False,
                "tblproperties": {"enableChangeDataFeed": "true"},
            },
        }

# %%
class StarWarsSilver(silver.Silver):
    def custom_filter(self, sdf: DataFrame, table: str) -> DataFrame:
        return sdf.where("uid <= '25'")

    def custom_transform(self, sdf: DataFrame, table: str) -> DataFrame:
        sdf = sdf.withColumn(
            "properties", F.from_json(F.col("properties"), DDL_SCHEMAS[table])
        )
        sdf = sdf.withColumn("uid", F.col("uid").cast("int"))
        return sdf

    def add_dummy_col(self, sdf: DataFrame, table: str) -> DataFrame:
        return sdf.withColumn("dummy_col", F.lit("dummy"))
    
silver_instance = StarWarsSilver(
    spark, catalog=CATALOG, source_schema="bronze", target_schema="silver", config=config
)

# %%
silver_instance.execute("people", "planets")

# %%
sdf = spark.sql(f"SELECT * FROM {CATALOG}.silver.people")
print(f"No. Rows: {sdf.count()}")
sdf.show(100, truncate=False)
# Out:
# No. Rows: 82
# +--------------------------+--------------------------+---------------------+---+------------------------------------+-----+
# |LH_SilverTS               |LH_BronzeTS               |name                 |uid|url                                 |dummy|
# +--------------------------+--------------------------+---------------------+---+------------------------------------+-----+
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Cliegg Lars          |62 |https://www.swapi.tech/api/people/62|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Poggle the Lesser    |63 |https://www.swapi.tech/api/people/63|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Luminara Unduli      |64 |https://www.swapi.tech/api/people/64|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Barriss Offee        |65 |https://www.swapi.tech/api/people/65|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Dormé                |66 |https://www.swapi.tech/api/people/66|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Dooku                |67 |https://www.swapi.tech/api/people/67|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Bail Prestor Organa  |68 |https://www.swapi.tech/api/people/68|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Jango Fett           |69 |https://www.swapi.tech/api/people/69|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Zam Wesell           |70 |https://www.swapi.tech/api/people/70|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Dexter Jettster      |71 |https://www.swapi.tech/api/people/71|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Lama Su              |72 |https://www.swapi.tech/api/people/72|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Taun We              |73 |https://www.swapi.tech/api/people/73|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Jocasta Nu           |74 |https://www.swapi.tech/api/people/74|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|R4-P17               |75 |https://www.swapi.tech/api/people/75|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Wat Tambor           |76 |https://www.swapi.tech/api/people/76|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|San Hill             |77 |https://www.swapi.tech/api/people/77|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Shaak Ti             |78 |https://www.swapi.tech/api/people/78|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Grievous             |79 |https://www.swapi.tech/api/people/79|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Tarfful              |80 |https://www.swapi.tech/api/people/80|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Raymus Antilles      |81 |https://www.swapi.tech/api/people/81|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Sly Moore            |82 |https://www.swapi.tech/api/people/82|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Tion Medon           |83 |https://www.swapi.tech/api/people/83|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Quarsh Panaka        |42 |https://www.swapi.tech/api/people/42|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Shmi Skywalker       |43 |https://www.swapi.tech/api/people/43|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Darth Maul           |44 |https://www.swapi.tech/api/people/44|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Bib Fortuna          |45 |https://www.swapi.tech/api/people/45|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Ayla Secura          |46 |https://www.swapi.tech/api/people/46|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Ratts Tyerel         |47 |https://www.swapi.tech/api/people/47|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Dud Bolt             |48 |https://www.swapi.tech/api/people/48|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Gasgano              |49 |https://www.swapi.tech/api/people/49|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Ben Quadinaros       |50 |https://www.swapi.tech/api/people/50|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Mace Windu           |51 |https://www.swapi.tech/api/people/51|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Ki-Adi-Mundi         |52 |https://www.swapi.tech/api/people/52|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Kit Fisto            |53 |https://www.swapi.tech/api/people/53|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Eeth Koth            |54 |https://www.swapi.tech/api/people/54|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Adi Gallia           |55 |https://www.swapi.tech/api/people/55|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Saesee Tiin          |56 |https://www.swapi.tech/api/people/56|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Yarael Poof          |57 |https://www.swapi.tech/api/people/57|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Plo Koon             |58 |https://www.swapi.tech/api/people/58|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Mas Amedda           |59 |https://www.swapi.tech/api/people/59|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Gregar Typho         |60 |https://www.swapi.tech/api/people/60|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Cordé                |61 |https://www.swapi.tech/api/people/61|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Luke Skywalker       |1  |https://www.swapi.tech/api/people/1 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|C-3PO                |2  |https://www.swapi.tech/api/people/2 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|R2-D2                |3  |https://www.swapi.tech/api/people/3 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Darth Vader          |4  |https://www.swapi.tech/api/people/4 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Leia Organa          |5  |https://www.swapi.tech/api/people/5 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Owen Lars            |6  |https://www.swapi.tech/api/people/6 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Beru Whitesun lars   |7  |https://www.swapi.tech/api/people/7 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|R5-D4                |8  |https://www.swapi.tech/api/people/8 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Biggs Darklighter    |9  |https://www.swapi.tech/api/people/9 |dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Obi-Wan Kenobi       |10 |https://www.swapi.tech/api/people/10|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Anakin Skywalker     |11 |https://www.swapi.tech/api/people/11|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Wilhuff Tarkin       |12 |https://www.swapi.tech/api/people/12|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Chewbacca            |13 |https://www.swapi.tech/api/people/13|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Han Solo             |14 |https://www.swapi.tech/api/people/14|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Greedo               |15 |https://www.swapi.tech/api/people/15|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Jabba Desilijic Tiure|16 |https://www.swapi.tech/api/people/16|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Wedge Antilles       |18 |https://www.swapi.tech/api/people/18|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Jek Tono Porkins     |19 |https://www.swapi.tech/api/people/19|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Yoda                 |20 |https://www.swapi.tech/api/people/20|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Palpatine            |21 |https://www.swapi.tech/api/people/21|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Boba Fett            |22 |https://www.swapi.tech/api/people/22|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|IG-88                |23 |https://www.swapi.tech/api/people/23|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Bossk                |24 |https://www.swapi.tech/api/people/24|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Lando Calrissian     |25 |https://www.swapi.tech/api/people/25|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Lobot                |26 |https://www.swapi.tech/api/people/26|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Ackbar               |27 |https://www.swapi.tech/api/people/27|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Mon Mothma           |28 |https://www.swapi.tech/api/people/28|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Arvel Crynyd         |29 |https://www.swapi.tech/api/people/29|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Wicket Systri Warrick|30 |https://www.swapi.tech/api/people/30|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Nien Nunb            |31 |https://www.swapi.tech/api/people/31|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Qui-Gon Jinn         |32 |https://www.swapi.tech/api/people/32|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Nute Gunray          |33 |https://www.swapi.tech/api/people/33|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Finis Valorum        |34 |https://www.swapi.tech/api/people/34|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Padmé Amidala        |35 |https://www.swapi.tech/api/people/35|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Jar Jar Binks        |36 |https://www.swapi.tech/api/people/36|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Roos Tarpals         |37 |https://www.swapi.tech/api/people/37|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Rugor Nass           |38 |https://www.swapi.tech/api/people/38|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Ric Olié             |39 |https://www.swapi.tech/api/people/39|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Watto                |40 |https://www.swapi.tech/api/people/40|dummy|
# |2025-02-18 21:12:40.344626|2025-02-18 21:11:09.352098|Sebulba              |41 |https://www.swapi.tech/api/people/41|dummy|
# +--------------------------+--------------------------+---------------------+---+------------------------------------+-----+

# %%
sdf = spark.sql(f"SELECT * FROM {CATALOG}.silver.planets")
print(f"No. Rows: {sdf.count()}")
sdf.show(100, truncate=False)
# Out:
# No. Rows: 60
# +--------------------------+-------------------------+--------------+---+-------------------------------------+-----+
# |LH_SilverTS               |LH_BronzeTS              |name          |uid|url                                  |dummy|
# +--------------------------+-------------------------+--------------+---+-------------------------------------+-----+
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Mygeeto       |16 |https://www.swapi.tech/api/planets/16|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Felucia       |17 |https://www.swapi.tech/api/planets/17|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Cato Neimoidia|18 |https://www.swapi.tech/api/planets/18|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Saleucami     |19 |https://www.swapi.tech/api/planets/19|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Stewjon       |20 |https://www.swapi.tech/api/planets/20|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Eriadu        |21 |https://www.swapi.tech/api/planets/21|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Corellia      |22 |https://www.swapi.tech/api/planets/22|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Rodia         |23 |https://www.swapi.tech/api/planets/23|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Nal Hutta     |24 |https://www.swapi.tech/api/planets/24|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Dantooine     |25 |https://www.swapi.tech/api/planets/25|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Bestine IV    |26 |https://www.swapi.tech/api/planets/26|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Ord Mantell   |27 |https://www.swapi.tech/api/planets/27|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|unknown       |28 |https://www.swapi.tech/api/planets/28|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Trandosha     |29 |https://www.swapi.tech/api/planets/29|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Socorro       |30 |https://www.swapi.tech/api/planets/30|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Mon Cala      |31 |https://www.swapi.tech/api/planets/31|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Chandrila     |32 |https://www.swapi.tech/api/planets/32|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Sullust       |33 |https://www.swapi.tech/api/planets/33|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Toydaria      |34 |https://www.swapi.tech/api/planets/34|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Malastare     |35 |https://www.swapi.tech/api/planets/35|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Dathomir      |36 |https://www.swapi.tech/api/planets/36|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Ryloth        |37 |https://www.swapi.tech/api/planets/37|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Aleen Minor   |38 |https://www.swapi.tech/api/planets/38|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Vulpter       |39 |https://www.swapi.tech/api/planets/39|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Troiken       |40 |https://www.swapi.tech/api/planets/40|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Tund          |41 |https://www.swapi.tech/api/planets/41|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Haruun Kal    |42 |https://www.swapi.tech/api/planets/42|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Cerea         |43 |https://www.swapi.tech/api/planets/43|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Glee Anselm   |44 |https://www.swapi.tech/api/planets/44|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Iridonia      |45 |https://www.swapi.tech/api/planets/45|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Tatooine      |1  |https://www.swapi.tech/api/planets/1 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Alderaan      |2  |https://www.swapi.tech/api/planets/2 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Yavin IV      |3  |https://www.swapi.tech/api/planets/3 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Hoth          |4  |https://www.swapi.tech/api/planets/4 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Dagobah       |5  |https://www.swapi.tech/api/planets/5 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Bespin        |6  |https://www.swapi.tech/api/planets/6 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Endor         |7  |https://www.swapi.tech/api/planets/7 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Naboo         |8  |https://www.swapi.tech/api/planets/8 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Coruscant     |9  |https://www.swapi.tech/api/planets/9 |dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Kamino        |10 |https://www.swapi.tech/api/planets/10|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Geonosis      |11 |https://www.swapi.tech/api/planets/11|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Utapau        |12 |https://www.swapi.tech/api/planets/12|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Mustafar      |13 |https://www.swapi.tech/api/planets/13|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Kashyyyk      |14 |https://www.swapi.tech/api/planets/14|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Polis Massa   |15 |https://www.swapi.tech/api/planets/15|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Tholoth       |46 |https://www.swapi.tech/api/planets/46|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Iktotch       |47 |https://www.swapi.tech/api/planets/47|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Quermia       |48 |https://www.swapi.tech/api/planets/48|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Dorin         |49 |https://www.swapi.tech/api/planets/49|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Champala      |50 |https://www.swapi.tech/api/planets/50|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Mirial        |51 |https://www.swapi.tech/api/planets/51|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Serenno       |52 |https://www.swapi.tech/api/planets/52|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Concord Dawn  |53 |https://www.swapi.tech/api/planets/53|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Zolan         |54 |https://www.swapi.tech/api/planets/54|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Ojom          |55 |https://www.swapi.tech/api/planets/55|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Skako         |56 |https://www.swapi.tech/api/planets/56|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Muunilinst    |57 |https://www.swapi.tech/api/planets/57|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Shili         |58 |https://www.swapi.tech/api/planets/58|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Kalee         |59 |https://www.swapi.tech/api/planets/59|dummy|
# |2025-02-18 21:13:31.286513|2025-02-18 21:12:02.21629|Umbara        |60 |https://www.swapi.tech/api/planets/60|dummy|
# +--------------------------+-------------------------+--------------+---+-------------------------------------+-----+

# %%
sdf = spark.sql(f"DESCRIBE HISTORY {CATALOG}.silver.planets")
sdf.show(100, truncate=False)
# Out:
# +-------+-----------------------+------+--------+---------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+--------+---------+-----------+-----------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-----------------------------------+
# |version|timestamp              |userId|userName|operation                        |operationParameters                                                                                                                                                                                             |job |notebook|clusterId|readVersion|isolationLevel   |isBlindAppend|operationMetrics                                                                                                                                                                                                                   |userMetadata|engineInfo                         |
# +-------+-----------------------+------+--------+---------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+--------+---------+-----------+-----------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-----------------------------------+
# |12     |2025-02-18 21:14:18.306|NULL  |NULL    |VACUUM END                       |{status -> COMPLETED}                                                                                                                                                                                           |NULL|NULL    |NULL     |11         |SnapshotIsolation|true         |{numDeletedFiles -> 0, numVacuumedDirectories -> 1}                                                                                                                                                                                |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |11     |2025-02-18 21:14:12.841|NULL  |NULL    |VACUUM START                     |{retentionCheckEnabled -> true, defaultRetentionMillis -> 604800000, specifiedRetentionMillis -> 604800000}                                                                                                     |NULL|NULL    |NULL     |10         |SnapshotIsolation|true         |{numFilesToDelete -> 0, sizeOfDataToDelete -> 0}                                                                                                                                                                                   |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |10     |2025-02-18 21:13:59.83 |NULL  |NULL    |OPTIMIZE                         |{predicate -> [], zOrderBy -> [], clusterBy -> [], auto -> false}                                                                                                                                               |NULL|NULL    |NULL     |9          |SnapshotIsolation|false        |{numRemovedFiles -> 4, numRemovedBytes -> 8971, p25FileSize -> 4241, numDeletionVectorsRemoved -> 0, minFileSize -> 4241, numAddedFiles -> 1, maxFileSize -> 4241, p75FileSize -> 4241, p50FileSize -> 4241, numAddedBytes -> 4241}|NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |9      |2025-02-18 21:13:55.771|NULL  |NULL    |SET TBLPROPERTIES                |{properties -> {"enableChangeDataFeed":"true"}}                                                                                                                                                                 |NULL|NULL    |NULL     |8          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |8      |2025-02-18 21:13:52.907|NULL  |NULL    |SET TBLPROPERTIES                |{properties -> {"delta.enableTypeWidening":"false"}}                                                                                                                                                            |NULL|NULL    |NULL     |7          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |7      |2025-02-18 21:13:50.446|NULL  |NULL    |SET TBLPROPERTIES                |{properties -> {"delta.enableRowTracking":"true"}}                                                                                                                                                              |NULL|NULL    |NULL     |6          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |6      |2025-02-18 21:13:48.418|NULL  |NULL    |ROW TRACKING BACKFILL            |{batchId -> 0}                                                                                                                                                                                                  |NULL|NULL    |NULL     |5          |SnapshotIsolation|false        |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |5      |2025-02-18 21:13:46.045|NULL  |NULL    |UPGRADE PROTOCOL                 |{newProtocol -> {"minReaderVersion":3,"minWriterVersion":7,"readerFeatures":["deletionVectors"],"writerFeatures":["deletionVectors","domainMetadata","rowTracking","invariants","changeDataFeed","appendOnly"]}}|NULL|NULL    |NULL     |4          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |4      |2025-02-18 21:13:44.02 |NULL  |NULL    |SET TBLPROPERTIES                |{properties -> {"delta.enableChangeDataFeed":"true"}}                                                                                                                                                           |NULL|NULL    |NULL     |3          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |3      |2025-02-18 21:13:41.984|NULL  |NULL    |SET TBLPROPERTIES                |{properties -> {"delta.autoOptimize.optimizeWrite":"true"}}                                                                                                                                                     |NULL|NULL    |NULL     |2          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |2      |2025-02-18 21:13:39.075|NULL  |NULL    |SET TBLPROPERTIES                |{properties -> {"delta.autoOptimize.autoCompact":"true"}}                                                                                                                                                       |NULL|NULL    |NULL     |1          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |1      |2025-02-18 21:13:34.178|NULL  |NULL    |SET TBLPROPERTIES                |{properties -> {"delta.enableDeletionVectors":"true"}}                                                                                                                                                          |NULL|NULL    |NULL     |0          |Serializable     |true         |{}                                                                                                                                                                                                                                 |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# |0      |2025-02-18 21:13:31.998|NULL  |NULL    |CREATE OR REPLACE TABLE AS SELECT|{partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}                                                                                                                  |NULL|NULL    |NULL     |NULL       |Serializable     |false        |{numFiles -> 4, numOutputRows -> 60, numOutputBytes -> 8971}                                                                                                                                                                       |NULL        |Apache-Spark/3.5.4 Delta-Lake/3.3.0|
# +-------+-----------------------+------+--------+---------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+--------+---------+-----------+-----------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-----------------------------------+

# %% [markdown]
# # 6 Clean Up

# %%
spark.sql(f"DROP SCHEMA IF EXISTS {CATALOG}.bronze CASCADE")
spark.sql(f"DROP SCHEMA IF EXISTS {CATALOG}.silver CASCADE")
# Out:
# DataFrame[]
