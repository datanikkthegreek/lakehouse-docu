# %%
import requests
import os
import sys
import platform
from lakehouse.spark import bronze, silver
from pyspark.sql import DataFrame, SparkSession
from delta import configure_spark_with_delta_pip
from pyspark.sql import functions as F
from pyspark.sql import DataFrame
import json

# %%
if platform.system() == "Windows":
    os.environ["PYSPARK_PYTHON"] = sys.executable
    os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable
    print("Adding Python ENV variables on Windows")
# Out:
# Adding Python ENV variables on Windows

# %%
builder = (
    SparkSession.builder.appName("Data with Nikk the Greek Spark Session")
    .master("local[4]")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config(
        "spark.sql.catalog.spark_catalog",
        "org.apache.spark.sql.delta.catalog.DeltaCatalog",
    )
)
spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
CATALOG = spark.catalog.currentCatalog()

# %% [markdown]
# # 1. Set Up and Bronze Data

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.bronze")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.silver")
# Out:
# DataFrame[]

# %%
options = {"catalog": CATALOG, "target_schema": "bronze"}

# %%
@F.udf(returnType="STRING")
def get_properties(url):
    json_request = requests.get(url).json()
    return json.dumps(json_request["result"]["properties"])

# %%
class StarWarsBronze(bronze.Bronze):
    def custom_load(self, table):
        results = []
        query = f"https://swapi.tech/api/{table}"
        json_request = requests.get(query).json()
        results.extend(json_request["results"])

        while json_request["next"]:
            json_request = requests.get(json_request["next"]).json()
            results.extend(json_request["results"])
        return spark.createDataFrame(results)

    def custom_transform(self, df: DataFrame, table: str) -> DataFrame:
        return df.withColumn("properties", get_properties(F.col("url")))


bronze_instance = StarWarsBronze(spark, **options)

# %%
bronze_instance.load().transform().write(mode="overwrite").execute("people", "planets")
# Out:
# 2025-03-16 07:55:32 | people | execute | Started
# 2025-03-16 07:55:32 | people | execute | Started
# 2025-03-16 07:55:32 | people | load | Started
# 2025-03-16 07:55:37 | people | load | Completed in 0.08 min
# 2025-03-16 07:55:37 | people | transform | Started
# 2025-03-16 07:55:37 | people | transform | Completed in 0.0 min
# 2025-03-16 07:55:37 | people | write | Started
# 2025-03-16 07:56:02 | people | write | Completed in 0.4 min
# 2025-03-16 07:56:02 | people | execute | Completed in 0.5 min
# 2025-03-16 07:56:02 | planets | execute | Started
# 2025-03-16 07:56:02 | planets | load | Started
# 2025-03-16 07:56:05 | planets | load | Completed in 0.03 min
# 2025-03-16 07:56:05 | planets | transform | Started
# 2025-03-16 07:56:05 | planets | transform | Completed in 0.0 min
# 2025-03-16 07:56:05 | planets | write | Started
# 2025-03-16 07:56:19 | planets | write | Completed in 0.23 min
# 2025-03-16 07:56:19 | planets | execute | Completed in 0.28 min
# 2025-03-16 07:56:19 | people | execute | Completed in 0.78 min

# %%
df = spark.sql(f"SELECT * FROM {CATALOG}.bronze.people")
print(f"No. Rows: {df.count()}")
df.show()
# Out:
# No. Rows: 82
# +--------------------+-------------------+---+--------------------+--------------------+
# |         LH_BronzeTS|               name|uid|                 url|          properties|
# +--------------------+-------------------+---+--------------------+--------------------+
# |2025-03-16 07:55:...|        Cliegg Lars| 62|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|  Poggle the Lesser| 63|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|    Luminara Unduli| 64|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|      Barriss Offee| 65|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|              Dormé| 66|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|              Dooku| 67|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|Bail Prestor Organa| 68|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|         Jango Fett| 69|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|         Zam Wesell| 70|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|    Dexter Jettster| 71|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|            Lama Su| 72|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|            Taun We| 73|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|         Jocasta Nu| 74|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|             R4-P17| 75|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|         Wat Tambor| 76|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|           San Hill| 77|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|           Shaak Ti| 78|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|           Grievous| 79|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|            Tarfful| 80|https://www.swapi...|{"created": "2025...|
# |2025-03-16 07:55:...|    Raymus Antilles| 81|https://www.swapi...|{"created": "2025...|
# +--------------------+-------------------+---+--------------------+--------------------+
# only showing top 20 rows

# %%
df = spark.sql(f"SELECT * FROM {CATALOG}.bronze.planets")
print(f"No. Rows: {df.count()}")
df.show(truncate=False)
# Out:
# No. Rows: 60
# +--------------------------+-----------+---+-------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |LH_BronzeTS               |name       |uid|url                                  |properties                                                                                                                                                                                                                                                                                                                                                                                    |
# +--------------------------+-----------+---+-------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2025-03-16 07:56:05.266792|Mon Cala   |31 |https://www.swapi.tech/api/planets/31|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "100", "name": "Mon Cala", "diameter": "11030", "rotation_period": "21", "terrain": "oceans, reefs, islands", "gravity": "1", "orbital_period": "398", "population": "27000000000", "url": "https://www.swapi.tech/api/planets/31"}                                    |
# |2025-03-16 07:56:05.266792|Chandrila  |32 |https://www.swapi.tech/api/planets/32|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "40", "name": "Chandrila", "diameter": "13500", "rotation_period": "20", "terrain": "plains, forests", "gravity": "1", "orbital_period": "368", "population": "1200000000", "url": "https://www.swapi.tech/api/planets/32"}                                            |
# |2025-03-16 07:56:05.266792|Sullust    |33 |https://www.swapi.tech/api/planets/33|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "superheated", "surface_water": "5", "name": "Sullust", "diameter": "12780", "rotation_period": "20", "terrain": "mountains, volcanoes, rocky deserts", "gravity": "1", "orbital_period": "263", "population": "18500000000", "url": "https://www.swapi.tech/api/planets/33"}                        |
# |2025-03-16 07:56:05.266792|Toydaria   |34 |https://www.swapi.tech/api/planets/34|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "unknown", "name": "Toydaria", "diameter": "7900", "rotation_period": "21", "terrain": "swamps, lakes", "gravity": "1", "orbital_period": "184", "population": "11000000", "url": "https://www.swapi.tech/api/planets/34"}                                             |
# |2025-03-16 07:56:05.266792|Malastare  |35 |https://www.swapi.tech/api/planets/35|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "arid, temperate, tropical", "surface_water": "unknown", "name": "Malastare", "diameter": "18880", "rotation_period": "26", "terrain": "swamps, deserts, jungles, mountains", "gravity": "1.56", "orbital_period": "201", "population": "2000000000", "url": "https://www.swapi.tech/api/planets/35"}|
# |2025-03-16 07:56:05.266792|Dathomir   |36 |https://www.swapi.tech/api/planets/36|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "unknown", "name": "Dathomir", "diameter": "10480", "rotation_period": "24", "terrain": "forests, deserts, savannas", "gravity": "0.9", "orbital_period": "491", "population": "5200", "url": "https://www.swapi.tech/api/planets/36"}                                 |
# |2025-03-16 07:56:05.266792|Ryloth     |37 |https://www.swapi.tech/api/planets/37|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate, arid, subartic", "surface_water": "5", "name": "Ryloth", "diameter": "10600", "rotation_period": "30", "terrain": "mountains, valleys, deserts, tundra", "gravity": "1", "orbital_period": "305", "population": "1500000000", "url": "https://www.swapi.tech/api/planets/37"}            |
# |2025-03-16 07:56:05.266792|Aleen Minor|38 |https://www.swapi.tech/api/planets/38|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "unknown", "surface_water": "unknown", "name": "Aleen Minor", "diameter": "unknown", "rotation_period": "unknown", "terrain": "unknown", "gravity": "unknown", "orbital_period": "unknown", "population": "unknown", "url": "https://www.swapi.tech/api/planets/38"}                                 |
# |2025-03-16 07:56:05.266792|Vulpter    |39 |https://www.swapi.tech/api/planets/39|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate, artic", "surface_water": "unknown", "name": "Vulpter", "diameter": "14900", "rotation_period": "22", "terrain": "urban, barren", "gravity": "1", "orbital_period": "391", "population": "421000000", "url": "https://www.swapi.tech/api/planets/39"}                                     |
# |2025-03-16 07:56:05.266792|Troiken    |40 |https://www.swapi.tech/api/planets/40|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "unknown", "surface_water": "unknown", "name": "Troiken", "diameter": "unknown", "rotation_period": "unknown", "terrain": "desert, tundra, rainforests, mountains", "gravity": "unknown", "orbital_period": "unknown", "population": "unknown", "url": "https://www.swapi.tech/api/planets/40"}      |
# |2025-03-16 07:56:05.266792|Tund       |41 |https://www.swapi.tech/api/planets/41|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "unknown", "surface_water": "unknown", "name": "Tund", "diameter": "12190", "rotation_period": "48", "terrain": "barren, ash", "gravity": "unknown", "orbital_period": "1770", "population": "0", "url": "https://www.swapi.tech/api/planets/41"}                                                    |
# |2025-03-16 07:56:05.266792|Haruun Kal |42 |https://www.swapi.tech/api/planets/42|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "unknown", "name": "Haruun Kal", "diameter": "10120", "rotation_period": "25", "terrain": "toxic cloudsea, plateaus, volcanoes", "gravity": "0.98", "orbital_period": "383", "population": "705300", "url": "https://www.swapi.tech/api/planets/42"}                   |
# |2025-03-16 07:56:05.266792|Cerea      |43 |https://www.swapi.tech/api/planets/43|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "20", "name": "Cerea", "diameter": "unknown", "rotation_period": "27", "terrain": "verdant", "gravity": "1", "orbital_period": "386", "population": "450000000", "url": "https://www.swapi.tech/api/planets/43"}                                                       |
# |2025-03-16 07:56:05.266792|Glee Anselm|44 |https://www.swapi.tech/api/planets/44|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "tropical, temperate", "surface_water": "80", "name": "Glee Anselm", "diameter": "15600", "rotation_period": "33", "terrain": "lakes, islands, swamps, seas", "gravity": "1", "orbital_period": "206", "population": "500000000", "url": "https://www.swapi.tech/api/planets/44"}                    |
# |2025-03-16 07:56:05.266792|Iridonia   |45 |https://www.swapi.tech/api/planets/45|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "unknown", "surface_water": "unknown", "name": "Iridonia", "diameter": "unknown", "rotation_period": "29", "terrain": "rocky canyons, acid pools", "gravity": "unknown", "orbital_period": "413", "population": "unknown", "url": "https://www.swapi.tech/api/planets/45"}                           |
# |2025-03-16 07:56:05.266792|Tholoth    |46 |https://www.swapi.tech/api/planets/46|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "unknown", "surface_water": "unknown", "name": "Tholoth", "diameter": "unknown", "rotation_period": "unknown", "terrain": "unknown", "gravity": "unknown", "orbital_period": "unknown", "population": "unknown", "url": "https://www.swapi.tech/api/planets/46"}                                     |
# |2025-03-16 07:56:05.266792|Iktotch    |47 |https://www.swapi.tech/api/planets/47|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "arid, rocky, windy", "surface_water": "unknown", "name": "Iktotch", "diameter": "unknown", "rotation_period": "22", "terrain": "rocky", "gravity": "1", "orbital_period": "481", "population": "unknown", "url": "https://www.swapi.tech/api/planets/47"}                                           |
# |2025-03-16 07:56:05.266792|Quermia    |48 |https://www.swapi.tech/api/planets/48|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "unknown", "surface_water": "unknown", "name": "Quermia", "diameter": "unknown", "rotation_period": "unknown", "terrain": "unknown", "gravity": "unknown", "orbital_period": "unknown", "population": "unknown", "url": "https://www.swapi.tech/api/planets/48"}                                     |
# |2025-03-16 07:56:05.266792|Dorin      |49 |https://www.swapi.tech/api/planets/49|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "unknown", "name": "Dorin", "diameter": "13400", "rotation_period": "22", "terrain": "unknown", "gravity": "1", "orbital_period": "409", "population": "unknown", "url": "https://www.swapi.tech/api/planets/49"}                                                      |
# |2025-03-16 07:56:05.266792|Champala   |50 |https://www.swapi.tech/api/planets/50|{"created": "2025-03-16T00:20:27.885Z", "edited": "2025-03-16T00:20:27.885Z", "climate": "temperate", "surface_water": "unknown", "name": "Champala", "diameter": "unknown", "rotation_period": "27", "terrain": "oceans, rainforests, plateaus", "gravity": "1", "orbital_period": "318", "population": "3500000000", "url": "https://www.swapi.tech/api/planets/50"}                        |
# +--------------------------+-----------+---+-------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
ddl_schema_planets = "diameter STRING, rotation_period STRING, orbital_period STRING, gravity STRING, population STRING, climate STRING, terrain STRING, surface_water STRING, created STRING, edited STRING, name STRING, url STRING"
ddl_schema_people = "height STRING, mass STRING, hair_color STRING, skin_color STRING, eye_color STRING, birth_year STRING, gender STRING, created STRING, edited STRING, name STRING, homeworld STRING, url STRING"
DDL_SCHEMAS = {"planets": ddl_schema_planets, "people": ddl_schema_people}

# %%
options = {
    "catalog": CATALOG,
    "source_schema": "bronze",
    "target_schema": "silver",
}

# %% [markdown]
# # 2 Overwrite

# %%
class StarWarsSilver(silver.Silver):
    def custom_filter(self, df: DataFrame, table: str) -> DataFrame:
        return df.where("uid <= '25'")

    def custom_transform(self, df: DataFrame, table: str) -> DataFrame:
        df = df.withColumn(
            "properties", F.from_json(F.col("properties"), DDL_SCHEMAS[table])
        )
        df = df.withColumn("uid", F.col("uid").cast("int"))
        return df

    def add_dummy_col(self, df: DataFrame, table: str) -> DataFrame:
        return df.withColumn("dummy_col", F.lit("dummy"))


silver_instance = StarWarsSilver(
    spark, catalog=CATALOG, source_schema="bronze", target_schema="silver"
)

# %%
silver_instance = silver_instance.load(filter="custom")
silver_instance.transform(
    transformation_order=[
        "add_dummy_col",
        "rename_columns",
        "tbl_transformations",
        "select_columns",
        "cast_column_types",
    ],
    rename_columns={
        "planets": {"dummy_col": "dummy"},
        "people": {"dummy_col": "dummy"},
    },
    select_columns={
        "planets": ["LH_BronzeTS", "name", "uid", "url", "dummy"],
        "people": ["LH_BronzeTS", "name", "uid", "url", "dummy"],
    },
    cast_column_types={
        "planets": {"dummy": "string", "id": "int"},
        "people": {"dummy": "string", "id": "int"},
    },
)
silver_instance.write(mode="overwrite").execute("people", "planets")
# Out:
# 2025-03-16 07:56:23 | people | execute | Started
# 2025-03-16 07:56:23 | people | execute | Started
# 2025-03-16 07:56:23 | people | load | Started
# 2025-03-16 07:56:23 | people | load | Completed in 0.0 min
# 2025-03-16 07:56:23 | people | transform | Started
# 2025-03-16 07:56:23 | people | transform | Completed in 0.0 min
# 2025-03-16 07:56:23 | people | write | Started
# 2025-03-16 07:56:25 | people | write | Completed in 0.03 min
# 2025-03-16 07:56:25 | people | execute | Completed in 0.03 min
# 2025-03-16 07:56:25 | planets | execute | Started
# 2025-03-16 07:56:25 | planets | load | Started
# 2025-03-16 07:56:25 | planets | load | Completed in 0.0 min
# 2025-03-16 07:56:25 | planets | transform | Started
# 2025-03-16 07:56:25 | planets | transform | Completed in 0.0 min
# 2025-03-16 07:56:25 | planets | write | Started
# 2025-03-16 07:56:27 | planets | write | Completed in 0.02 min
# 2025-03-16 07:56:27 | planets | execute | Completed in 0.02 min
# 2025-03-16 07:56:27 | people | execute | Completed in 0.05 min

# %%
df = spark.sql(f"SELECT * FROM {CATALOG}.silver.people")
print(f"No. Rows: {df.count()}")
df.show(100, truncate=False)
# Out:
# No. Rows: 17
# +--------------------------+--------------------------+---------------------+---+------------------------------------+-----+
# |LH_SilverTS               |LH_BronzeTS               |name                 |uid|url                                 |dummy|
# +--------------------------+--------------------------+---------------------+---+------------------------------------+-----+
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Luke Skywalker       |1  |https://www.swapi.tech/api/people/1 |dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|C-3PO                |2  |https://www.swapi.tech/api/people/2 |dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Obi-Wan Kenobi       |10 |https://www.swapi.tech/api/people/10|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Anakin Skywalker     |11 |https://www.swapi.tech/api/people/11|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Wilhuff Tarkin       |12 |https://www.swapi.tech/api/people/12|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Chewbacca            |13 |https://www.swapi.tech/api/people/13|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Han Solo             |14 |https://www.swapi.tech/api/people/14|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Greedo               |15 |https://www.swapi.tech/api/people/15|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Jabba Desilijic Tiure|16 |https://www.swapi.tech/api/people/16|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Wedge Antilles       |18 |https://www.swapi.tech/api/people/18|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Jek Tono Porkins     |19 |https://www.swapi.tech/api/people/19|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Yoda                 |20 |https://www.swapi.tech/api/people/20|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Palpatine            |21 |https://www.swapi.tech/api/people/21|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Boba Fett            |22 |https://www.swapi.tech/api/people/22|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|IG-88                |23 |https://www.swapi.tech/api/people/23|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Bossk                |24 |https://www.swapi.tech/api/people/24|dummy|
# |2025-03-16 07:56:23.917857|2025-03-16 07:55:38.380137|Lando Calrissian     |25 |https://www.swapi.tech/api/people/25|dummy|
# +--------------------------+--------------------------+---------------------+---+------------------------------------+-----+

# %%
df = spark.sql(f"SELECT * FROM {CATALOG}.silver.planets")
print(f"No. Rows: {df.count()}")
df.show(100, truncate=False)
# Out:
# No. Rows: 18
# +--------------------------+--------------------------+--------------+---+-------------------------------------+-----+
# |LH_SilverTS               |LH_BronzeTS               |name          |uid|url                                  |dummy|
# +--------------------------+--------------------------+--------------+---+-------------------------------------+-----+
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Mygeeto       |16 |https://www.swapi.tech/api/planets/16|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Felucia       |17 |https://www.swapi.tech/api/planets/17|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Cato Neimoidia|18 |https://www.swapi.tech/api/planets/18|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Saleucami     |19 |https://www.swapi.tech/api/planets/19|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Stewjon       |20 |https://www.swapi.tech/api/planets/20|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Eriadu        |21 |https://www.swapi.tech/api/planets/21|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Corellia      |22 |https://www.swapi.tech/api/planets/22|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Rodia         |23 |https://www.swapi.tech/api/planets/23|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Nal Hutta     |24 |https://www.swapi.tech/api/planets/24|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Dantooine     |25 |https://www.swapi.tech/api/planets/25|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Tatooine      |1  |https://www.swapi.tech/api/planets/1 |dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Alderaan      |2  |https://www.swapi.tech/api/planets/2 |dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Kamino        |10 |https://www.swapi.tech/api/planets/10|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Geonosis      |11 |https://www.swapi.tech/api/planets/11|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Utapau        |12 |https://www.swapi.tech/api/planets/12|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Mustafar      |13 |https://www.swapi.tech/api/planets/13|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Kashyyyk      |14 |https://www.swapi.tech/api/planets/14|dummy|
# |2025-03-16 07:56:25.983587|2025-03-16 07:56:05.266792|Polis Massa   |15 |https://www.swapi.tech/api/planets/15|dummy|
# +--------------------------+--------------------------+--------------+---+-------------------------------------+-----+

# %% [markdown]
# # 6 Clean Up

# %%
spark.sql(f"DROP SCHEMA IF EXISTS {CATALOG}.bronze CASCADE")
spark.sql(f"DROP SCHEMA IF EXISTS {CATALOG}.silver CASCADE")
spark.stop()
