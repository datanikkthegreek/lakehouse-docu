# %%
from lakehouse.etl import ETL

# %%
allowed_funcs = [
    func
    for func in dir(ETL)
    if callable(getattr(ETL, func)) and not func.startswith("_")
]

# %%
allowed_funcs
# Out:
# ['cast_column_types',
#  'custom_filter',
#  'custom_load',
#  'custom_transform',
#  'custom_write',
#  'default_transform',
#  'execute',
#  'get_delta_merge_builder',
#  'get_replace_condition',
#  'load',
#  'optimize',
#  'path',
#  'rename_columns',
#  'select_columns',
#  'tblproperties',
#  'transform',
#  'write']

# %%
Load:

transform:
['custom_transform', 'default_transform', 'cast_column_types', 'rename_columns', 'select_columns']

write:
